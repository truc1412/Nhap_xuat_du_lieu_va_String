# %%
import turtle as t
pen=t.Turtle()
t.bgcolor("black")
pen.speed(200)
pen.pensize(4)
pen.pencolor("cyan")
pen.penup()
pen.fillcolor ("blue")
pen.goto(-150,0)
pen.pendown()
pen.begin_fill()
pen.forward(200)
pen.left(90)
pen.forward(100)
pen.left(90)
pen.forward(200)
pen.left(90)
pen.forward(100)
pen.end_fill()
pen.fillcolor ("red")
pen.begin_fill()
pen.backward(100)
pen.left(90)
pen.forward(125)
pen.left(135)
pen.forward(90)
pen.left(90)
pen.forward(90)
pen.right(45)
pen.end_fill()


pen.penup()
pen.goto(-25,0)
pen.pendown()
pen.fillcolor ("yellow")
pen.begin_fill()
pen.forward(50)
pen.right(90)
pen.forward(75)
pen.right(90)
pen.forward(50)
pen.right(90)
pen.forward(75)
pen.right(180)
pen.end_fill()

pen.penup()
pen.goto(-65,140)
pen.fillcolor ("orange")
pen.begin_fill()
pen.pendown()
pen.forward(20)
pen.right(90)
pen.forward(30)
pen.right(90)
pen.forward(50)
pen.end_fill()
pen.penup()
pen.goto(-35,180)
pen.pendown()
pen.right(180)
pen.forward(40)
pen.penup()
pen.goto(-50,180)
pen.pendown()
pen.forward(20)

pen.penup()
pen.goto(195,-50)
pen.pendown()
pen.fillcolor ("gray")
pen.begin_fill()
pen.left(90)
pen.forward(40)
pen.right(95)
pen.forward(90)
pen.right(85)
pen.forward(25)
pen.right(85)
pen.forward(90)
pen.end_fill()

pen.penup()
pen.goto(180,40)
pen.right(95)
pen.pendown()
pen.fillcolor ("green")
pen.forward(90)
pen.left(45)
pen.backward(120)
pen.left(90)
pen.forward(120)
pen.left(45)
pen.backward(90)
pen.end_fill()

pen.penup()
pen.goto(180,125)
pen.pendown()
pen.fillcolor ("olive")
pen.begin_fill()
pen.forward(60)
pen.right(45)
pen.backward(90)
pen.right(90)
pen.forward(90)
pen.right(45)
pen.backward(70)
pen.end_fill()


pen.penup()
pen.goto(180,190)
pen.pendown()
pen.fillcolor ("lime")
pen.begin_fill()
pen.forward(45)
pen.left(45)
pen.backward(60)
pen.left(90)
pen.forward(60)
pen.left(45)
pen.backward(45)
pen.end_fill()
# cây nhỏ
pen.penup()
pen.goto(-200,-90)
pen.pendown()
pen.fillcolor ("gray")
pen.begin_fill()
pen.left(180)
pen.forward(20)
pen.right(95)
pen.forward(45)
pen.right(85)
pen.forward(10)
pen.right(85)
pen.forward(45)
pen.end_fill()

pen.penup()
pen.goto(-215,-45)
pen.right(95)
pen.pendown()
pen.fillcolor ("green")
pen.begin_fill()
pen.forward(40)
pen.left(45)
pen.backward(60)
pen.left(90)
pen.forward(60)
pen.left(45)
pen.backward(40)
pen.end_fill()

pen.penup()
pen.goto(-215,0)
pen.pendown()
pen.fillcolor ("olive")
pen.begin_fill()
pen.forward(30)
pen.right(45)
pen.backward(40)
pen.right(90)
pen.forward(40)
pen.right(45)
pen.backward(30)
pen.end_fill()

pen.penup()
pen.goto(-217,30)
pen.pendown()
pen.fillcolor ("lime")
pen.begin_fill()
pen.forward(10)
pen.left(45)
pen.backward(20)
pen.left(90)
pen.forward(20)
pen.left(45)
pen.backward(20)
pen.end_fill()

pen.penup()
pen.goto(-250,-250)
